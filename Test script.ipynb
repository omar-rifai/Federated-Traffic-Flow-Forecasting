# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

flow_file= "./data/PEMS04/PeMS04flow.csv"
csv_file = "./data/PEMS04/distance.csv"
graph_df = pd.read_csv(csv_file)
PeMS = pd.read_csv(flow_file, index_col=0)

# %%
int(len(PeMS)*0.7)
# Out:
# 11894

# %%
PeMS[:11894]
# Out:
#                          0      1      2     3     4      5     6     7     8  \
# 2018-01-01 00:00:00   62.0   56.0   90.0  32.0  19.0   68.0  24.0  24.0  31.0
# 2018-01-01 00:05:00   61.0   40.0   94.0  25.0  16.0   64.0  22.0   7.0  29.0
# 2018-01-01 00:10:00   71.0   28.0   79.0  36.0   9.0   60.0  25.0  11.0  25.0
# 2018-01-01 00:15:00   86.0   47.0   94.0  46.0  11.0   58.0  35.0  17.0  28.0
# 2018-01-01 00:20:00  103.0   36.0  154.0  68.0   9.0   56.0  56.0  37.0  36.0
# ...                    ...    ...    ...   ...   ...    ...   ...   ...   ...
# 2018-02-11 06:45:00  131.0   91.0  225.0  75.0  39.0  120.0  28.0  55.0  68.0
# 2018-02-11 06:50:00  139.0  105.0  178.0  59.0  61.0  152.0  26.0  55.0  76.0
# 2018-02-11 06:55:00  136.0  107.0  185.0  62.0  42.0  134.0  22.0  33.0  65.0
# 2018-02-11 07:00:00  115.0   93.0  176.0  57.0  45.0  136.0  21.0  50.0  69.0
# 2018-02-11 07:05:00   94.0  117.0  188.0  46.0  33.0  123.0  22.0  35.0  95.0
#
#                         9  ...    297    298   299    300    301    302  \
# 2018-01-01 00:00:00  31.0  ...    5.0   86.0  54.0   54.0   62.0   37.0
# 2018-01-01 00:05:00  33.0  ...    0.0   86.0  46.0   41.0   59.0   38.0
# 2018-01-01 00:10:00  46.0  ...    0.0   67.0  59.0   58.0   59.0   34.0
# 2018-01-01 00:15:00  46.0  ...   22.0  101.0  82.0   75.0   74.0   75.0
# 2018-01-01 00:20:00  55.0  ...    0.0   97.0  88.0  109.0   90.0   61.0
# ...                   ...  ...    ...    ...   ...    ...    ...    ...
# 2018-02-11 06:45:00  85.0  ...  203.0  178.0  72.0  111.0  147.0  105.0
# 2018-02-11 06:50:00  79.0  ...  173.0  193.0  76.0  114.0  118.0  107.0
# 2018-02-11 06:55:00  81.0  ...  173.0  180.0  75.0   92.0  122.0   77.0
# 2018-02-11 07:00:00  61.0  ...  154.0  183.0  77.0   85.0  136.0  106.0
# 2018-02-11 07:05:00  77.0  ...  175.0  148.0  80.0  122.0   99.0  108.0
#
#                        303    304   305    306
# 2018-01-01 00:00:00   90.0   56.0  48.0   38.0
# 2018-01-01 00:05:00   91.0   51.0  30.0   35.0
# 2018-01-01 00:10:00   56.0   67.0  31.0   45.0
# 2018-01-01 00:15:00   42.0  126.0  64.0   81.0
# 2018-01-01 00:20:00  127.0  200.0  63.0  104.0
# ...                    ...    ...   ...    ...
# 2018-02-11 06:45:00   63.0  158.0  59.0   97.0
# 2018-02-11 06:50:00   41.0  184.0  39.0   79.0
# 2018-02-11 06:55:00   65.0  128.0  66.0   71.0
# 2018-02-11 07:00:00   87.0  127.0  44.0   89.0
# 2018-02-11 07:05:00   65.0  108.0  51.0   82.0
#
# [11894 rows x 307 columns]
