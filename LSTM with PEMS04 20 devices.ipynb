# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# %%
flow_file= "./data/PEMS04/PEMS04.npz"
csv_file = "./data/PEMS04/distance.csv"

# %%
# 3 features flow, occupy, speed

# %%
import pandas as pd
data = np.load(flow_file)
df = pd.read_csv(csv_file)

# %%
df
# Out:
#      from   to   cost
# 0      73    5  352.6
# 1       5  154  347.2
# 2     154  263  392.9
# 3     263   56  440.8
# 4      56   96  374.6
# ..    ...  ...    ...
# 335    46  216  353.6
# 336   217   98  411.7
# 337    98   31    3.2
# 338   217   46  354.0
# 339    46   31  163.6
#
# [340 rows x 3 columns]

# %%
df.describe()
# Out:
#              from          to         cost
# count  340.000000  340.000000   340.000000
# mean   149.544118  146.241176   410.300588
# std     88.341793   89.092511   257.518655
# min      0.000000    0.000000     3.200000
# 25%     71.750000   66.750000   328.775000
# 50%    144.500000  139.500000   367.150000
# 75%    229.250000  226.500000   422.300000
# max    305.000000  306.000000  2712.100000

# %%
list(df['from'][:5])
# Out:
# [73, 5, 154, 263, 56]

# %%
data['data'].shape
# Out:
# (16992, 307, 3)

# %%
df['from'][:5]
# Out:
# 0     73
# 1      5
# 2    154
# 3    263
# 4     56
# Name: from, dtype: int64

# %% [markdown]
# # Time Series

# %%
data = np.load(flow_file)
TS = data['data']

# %%
TS.shape
# Out:
# (16992, 307, 3)

# %%
#flow,occupy and speed (flow: number of vehicule during this time point, occupy : percent of time a point on the road is occupied by vehicles.)
flow = TS[:,:,0]
occupy = TS[:,:,1]
speed = TS[:,:,2]

# %%
occupy.max()
# Out:
# 0.7716

# %%
# flow dict key is the sensor number and the value the traffic flow times serie
flow_dict={k:flow[:,k] for k in range(307)}
#creation of the datetime index
start_date = "2018-01-01 00:00:00"
end_date = "2018-02-28 23:55:00"
interval = "5min"
index = pd.date_range(start=start_date, end=end_date, freq=interval)

# %%
plt.figure(figsize=(28, 5))
plt.plot(index,flow_dict[0])
plt.title('Traffic flow PEMS04 sensor 0 at 5 min interval')
plt.show()
# traffic flow is measure in number of vehicule registered at time t registered in 5 minutes interval.

# %%
# list of the first 5 connected sensor, each sensor traffic flow is contained in PeMS 
sensor = set(df['from'][:20])
PeMS = {str(i):flow_dict[i] for i in sensor}

# %%
PeMS = pd.DataFrame(PeMS)

# %%
PeMS.isna().sum().describe()
# Out:
# count    20.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# dtype: float64

# %%
PeMS = PeMS.set_index(index)

# %%
105/24
# Out:
# 4.375

# %%
train_data= PeMS[:'2018-02-10 00:00:00']
val_data =  PeMS['2018-02-10 00:00:00':'2018-02-14 00:00:00']
test_data = PeMS['2018-02-14 00:00:00':]

# %%
to_hours = 12
to_days = 12*24
print(len(train_data)/to_days,len(val_data)/to_days,len(test_data)/to_days)
# Out:
# 40.00347222222222 4.003472222222222 15.0

# %%
n = len(sensor)
print(n)
# Out:
# 20

# %% [markdown]
# # New LSTM

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Define a PyTorch dataset to generate input/target pairs for the LSTM model
class TimeSeriesDataset(Dataset):
    def __init__(self, data, window_size, stride):
        self.data = data
        self.window_size = window_size
        self.stride = stride

    def __len__(self):
        return len(self.data) - self.window_size

    def __getitem__(self, idx):
        inputs = self.data[idx:idx+self.window_size]
        target = self.data[idx+self.window_size]
        return inputs, target

# %%
# Define your LSTM model here with 6 LSTM layers and 1 fully connected layer
class LSTMModel(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super().__init__()
        self.lstm = torch.nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %%
# Define the sliding window size and stride
window_size = 7
stride = 1
layers = 6
# Create datasets and data loaders for training, validation, and test sets
train_dataset = TimeSeriesDataset(train_data.values, window_size, stride)
val_dataset = TimeSeriesDataset(val_data.values, window_size, stride)
test_dataset = TimeSeriesDataset(test_data.values, window_size, stride)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Instantiate your LSTM model and define the loss function and optimizer
model = LSTMModel(input_size=n, hidden_size=32, num_layers=layers, output_size=n)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Train your model and evaluate on the validation set
num_epochs = 100
best_val_loss = float('inf')
train_losses = []
valid_losses = []
for epoch in range(num_epochs):
    train_loss = 0.0

    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs.float())
        loss = criterion(outputs, targets.float())
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_losses.append(loss.item())
    val_loss = 0.0
    
    for inputs, targets in val_loader:
        outputs = model(inputs.float())
        loss = criterion(outputs, targets.float())
        val_loss += loss.item()
        
    val_loss /= len(val_loader)
    valid_losses.append(val_loss)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), 'best_model_20.pth')
    
    print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}')
# Out:
# Epoch 1/100, Training Loss: 36608116.5859, Validation Loss: 96340.0088
# Epoch 2/100, Training Loss: 34270820.4844, Validation Loss: 90423.5935
# Epoch 3/100, Training Loss: 32211067.4297, Validation Loss: 84974.5979
# Epoch 4/100, Training Loss: 30287565.3164, Validation Loss: 79885.5351
# Epoch 5/100, Training Loss: 28490522.6406, Validation Loss: 75118.5207
# Epoch 6/100, Training Loss: 26810627.8867, Validation Loss: 70637.8721
# Epoch 7/100, Training Loss: 25225430.5430, Validation Loss: 66431.7969
# Epoch 8/100, Training Loss: 23731589.6641, Validation Loss: 62464.1930
# Epoch 9/100, Training Loss: 22329274.8008, Validation Loss: 58739.0239
# Epoch 10/100, Training Loss: 21004200.9922, Validation Loss: 55226.9357
# Epoch 11/100, Training Loss: 19763872.6680, Validation Loss: 51940.5937
# Epoch 12/100, Training Loss: 18593783.3066, Validation Loss: 48854.2961
# Epoch 13/100, Training Loss: 17497925.4727, Validation Loss: 45968.3105
# Epoch 14/100, Training Loss: 16477775.1855, Validation Loss: 43274.8672
# Epoch 15/100, Training Loss: 15518824.5566, Validation Loss: 40774.9076
# Epoch 16/100, Training Loss: 14636379.4746, Validation Loss: 38460.1671
# Epoch 17/100, Training Loss: 13810300.2070, Validation Loss: 36313.2794
# Epoch 18/100, Training Loss: 13048178.5664, Validation Loss: 34342.7393
# Epoch 19/100, Training Loss: 12350214.6660, Validation Loss: 32542.9144
# Epoch 20/100, Training Loss: 11713065.9707, Validation Loss: 30902.2042
# Epoch 21/100, Training Loss: 11129673.7109, Validation Loss: 29417.7477
# Epoch 22/100, Training Loss: 10605452.7246, Validation Loss: 28079.6110
# Epoch 23/100, Training Loss: 10130094.1660, Validation Loss: 26886.5501
# Epoch 24/100, Training Loss: 9708564.0312, Validation Loss: 25830.3008
# Epoch 25/100, Training Loss: 9334822.2148, Validation Loss: 24901.6055
# Epoch 26/100, Training Loss: 9005115.0898, Validation Loss: 24094.0325
# Epoch 27/100, Training Loss: 8718862.7832, Validation Loss: 23395.1328
# Epoch 28/100, Training Loss: 8470181.5312, Validation Loss: 22794.3241
# Epoch 29/100, Training Loss: 8257021.2656, Validation Loss: 22292.7474
# Epoch 30/100, Training Loss: 8076510.8555, Validation Loss: 21873.3466
# Epoch 31/100, Training Loss: 7925330.2715, Validation Loss: 21527.7424
# Epoch 32/100, Training Loss: 7800029.2344, Validation Loss: 21244.9286
# Epoch 33/100, Training Loss: 7697925.1387, Validation Loss: 21022.3599
# Epoch 34/100, Training Loss: 7616304.2832, Validation Loss: 20849.0078
# Epoch 35/100, Training Loss: 7551781.2490, Validation Loss: 20715.6658
# Epoch 36/100, Training Loss: 7499852.4346, Validation Loss: 20617.4729
# Epoch 37/100, Training Loss: 7460792.9336, Validation Loss: 20543.8977
# Epoch 38/100, Training Loss: 7430700.2520, Validation Loss: 20490.9336
# Epoch 39/100, Training Loss: 7408855.2900, Validation Loss: 20454.7082
# Epoch 40/100, Training Loss: 7394221.2783, Validation Loss: 20431.0996
# Epoch 41/100, Training Loss: 7383108.3037, Validation Loss: 20415.7080
# Epoch 42/100, Training Loss: 7376967.2646, Validation Loss: 20406.3265
# Epoch 43/100, Training Loss: 7371375.5898, Validation Loss: 20401.0527
# Epoch 44/100, Training Loss: 7368681.2617, Validation Loss: 20397.8197
# Epoch 45/100, Training Loss: 7367166.3916, Validation Loss: 20396.2097
# Epoch 46/100, Training Loss: 7181357.6543, Validation Loss: 11109.9686
# Epoch 47/100, Training Loss: 4357514.9014, Validation Loss: 9857.8987
# Epoch 48/100, Training Loss: 3519165.7554, Validation Loss: 8522.1507
# Epoch 49/100, Training Loss: 3261141.7446, Validation Loss: 8256.0178
# Epoch 50/100, Training Loss: 3059224.0469, Validation Loss: 7346.9392
# Epoch 51/100, Training Loss: 2871151.2012, Validation Loss: 7567.4641
# Epoch 52/100, Training Loss: 2842352.1123, Validation Loss: 7173.9564
# Epoch 53/100, Training Loss: 2977705.9331, Validation Loss: 6768.5573
# Epoch 54/100, Training Loss: 2562298.2588, Validation Loss: 6200.4803
# Epoch 55/100, Training Loss: 2518067.5474, Validation Loss: 6184.3320
# Epoch 56/100, Training Loss: 2566095.1660, Validation Loss: 6250.7272
# Epoch 57/100, Training Loss: 2504882.7583, Validation Loss: 6007.4048
# Epoch 58/100, Training Loss: 2450331.2617, Validation Loss: 5879.7044
# Epoch 59/100, Training Loss: 2409489.1245, Validation Loss: 5993.9833
# Epoch 60/100, Training Loss: 2318613.3384, Validation Loss: 5589.0839
# Epoch 61/100, Training Loss: 2174953.7451, Validation Loss: 5117.1592
# Epoch 62/100, Training Loss: 2075233.5737, Validation Loss: 5026.8993
# Epoch 63/100, Training Loss: 2025449.9724, Validation Loss: 4952.2893
# Epoch 64/100, Training Loss: 2008596.4065, Validation Loss: 4807.4733
# Epoch 65/100, Training Loss: 1994704.7300, Validation Loss: 4884.4761
# Epoch 66/100, Training Loss: 1991279.4812, Validation Loss: 4784.1989
# Epoch 67/100, Training Loss: 1998207.5833, Validation Loss: 4852.5707
# Epoch 68/100, Training Loss: 1943672.5205, Validation Loss: 4687.5117
# Epoch 69/100, Training Loss: 2062594.7222, Validation Loss: 4831.5790
# Epoch 70/100, Training Loss: 1969232.6960, Validation Loss: 4917.3547
# Epoch 71/100, Training Loss: 1946051.9956, Validation Loss: 4595.6201
# Epoch 72/100, Training Loss: 1912889.6963, Validation Loss: 4542.4194
# Epoch 73/100, Training Loss: 1938905.5496, Validation Loss: 4789.5533
# Epoch 74/100, Training Loss: 1930555.5510, Validation Loss: 4555.3564
# Epoch 75/100, Training Loss: 1905223.1201, Validation Loss: 4575.4741
# Epoch 76/100, Training Loss: 1933614.8044, Validation Loss: 4518.7739
# Epoch 77/100, Training Loss: 1917580.7542, Validation Loss: 4502.9541
# Epoch 78/100, Training Loss: 1878059.5811, Validation Loss: 4500.4970
# Epoch 79/100, Training Loss: 1891376.0010, Validation Loss: 5132.0400
# Epoch 80/100, Training Loss: 1895456.4773, Validation Loss: 4426.4700
# Epoch 81/100, Training Loss: 1953794.5164, Validation Loss: 4819.8375
# Epoch 82/100, Training Loss: 1894253.2471, Validation Loss: 4353.4495
# Epoch 83/100, Training Loss: 1850864.2068, Validation Loss: 4323.5915
# Epoch 84/100, Training Loss: 1855166.4670, Validation Loss: 4659.8354
# Epoch 85/100, Training Loss: 1854757.3687, Validation Loss: 4656.0755
# Epoch 86/100, Training Loss: 1821081.9841, Validation Loss: 4245.8211
# Epoch 87/100, Training Loss: 1813985.5181, Validation Loss: 4213.3165
# Epoch 88/100, Training Loss: 1802429.8516, Validation Loss: 4288.5172
# Epoch 89/100, Training Loss: 1906622.6343, Validation Loss: 4456.3361
# Epoch 90/100, Training Loss: 1868988.3857, Validation Loss: 4599.4680
# Epoch 91/100, Training Loss: 1897698.7566, Validation Loss: 4627.2916
# Epoch 92/100, Training Loss: 1881343.3416, Validation Loss: 4320.5830
# Epoch 93/100, Training Loss: 1830399.1448, Validation Loss: 4198.1903
# Epoch 94/100, Training Loss: 1843260.7314, Validation Loss: 4247.4889
# Epoch 95/100, Training Loss: 1864683.9358, Validation Loss: 4519.2273
# Epoch 96/100, Training Loss: 1863121.5745, Validation Loss: 4407.5295
# Epoch 97/100, Training Loss: 1843694.9980, Validation Loss: 4360.1119
# Epoch 98/100, Training Loss: 1840437.1228, Validation Loss: 4302.1951
# Epoch 99/100, Training Loss: 1818312.6238, Validation Loss: 4329.1674
# Epoch 100/100, Training Loss: 1822302.1306, Validation Loss: 4256.5285

# %%
len(train_losses)
# Out:
# 36000

# %%
plt.plot(valid_losses,label = 'Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.show()

# %%
model
# Out:
# LSTMModel(
#   (lstm): LSTM(20, 32, num_layers=6, batch_first=True)
#   (fc): Linear(in_features=32, out_features=20, bias=True)
# )

# %%
# Load the best model and evaluate on the test set
best_model =  LSTMModel(input_size=n, hidden_size=32, num_layers=layers, output_size=n)
best_model.load_state_dict(torch.load('best_model.pth'))
best_model.double()
best_model.eval()

# Evaluate the model on the test set
test_loss = 0.0
predictions = []
actuals = []
with torch.no_grad():
    for i, (inputs, targets) in enumerate(test_loader):
        inputs = inputs.to(device)
        targets = targets.to(device)
        x = torch.Tensor(inputs).unsqueeze(1).to(device)
        y = torch.Tensor(targets).unsqueeze(0).to(device)
        outputs = best_model(inputs)
        loss = criterion(outputs, targets)
        test_loss += loss.item()
        # Save the predictions and actual values for plotting later
        predictions.append(outputs.cpu().numpy())
        actuals.append(targets.cpu().numpy())
test_loss /= len(test_loader)
print(f"Test Loss: {test_loss:.4f}")
# Concatenate the predictions and actuals
predictions = np.concatenate(predictions, axis=0)
actuals = np.concatenate(actuals, axis=0)
# Out:
# Test Loss: 4541.2197

# %%
len(inputs)
# Out:
# 25

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
from random import randint
EPSILON = 1e-10
for i in range(10): 
    plt.figure(figsize=(28, 5))
    plt.title('Actual vs Prediction of sensor N° {}'.format(PeMS.columns[i]))
    y_pred = predictions[:,i]
    y_true = actuals[:,i]
    plt.plot(test_data.index[window_size:],y_true, label='Actuals')
    plt.plot(test_data.index[window_size:],y_pred, label='Predictions')
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    maape =  np.mean(np.arctan(np.abs((y_true - y_pred) / (y_true + EPSILON))))
    # Add evaluation metrics to the plot
    plt.annotate(f'MAE: {mae:.2f}', xy=(0.005, 0.6), xycoords='axes fraction')
    plt.annotate(f'RMSE: {rmse:.2f}', xy=(0.005, 0.54), xycoords='axes fraction')
    plt.annotate(f'MAAPE: {maape:.2f}', xy=(0.005, 0.5), xycoords='axes fraction')

    # Set x and y labels
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.legend()
    print(mae,rmse,maape)
    plt.show()
# Out:
# 14.755524866050806 19.50355047810351 0.2861969894891931
# 26.93739700695523 35.61854465745893 0.10700399613314976
# 24.665889913924797 33.10814871555164 0.193170402250331
# 47.01402870067402 62.75235993067618 0.1682605877680379
# 52.18218492931795 69.76099829046812 0.18498292566155664
# 48.45767687700955 63.228348435938464 0.13612096383742284
# 55.62968452600005 71.24131077903209 0.17569884275309666
# 45.655951359496406 60.427829958619135 0.19808373963108078
# 46.89215858373001 61.48712052541568 0.2077854209816105
# 97.21588497327306 123.94647262185191 0.30103714283433847
